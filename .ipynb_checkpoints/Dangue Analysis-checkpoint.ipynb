# %%
import pandas as pd

# %%
a=pd.read_csv("danguedata.csv")

# %%
a.head()
# Out:
#   Province ,Districts ,Jan ,Feb ,Mar ,Apr ,May ,Jun ,Jul ,Aug ,Sept ,Oct ,Nov ,Grand Total
# 0  3,306 KATHMANDU ,0,0,0,0,1,1,35,727,9891,2911,...
# 1  3,308 LALITPUR ,0,0,0,0,0,1,99,1558,6016,1809,...
# 2  3,307 BHAKTAPUR ,0,0,0,0,0,0,6,86,1151,4204,67...
# 3  3,312 MAKWANPUR ,0,0,0,0,0,0,221,337,2452,2220...
# 4  3,313 CHITAWAN ,0,0,0,0,0,3,4,24,995,1509,624,...

# %%
c=a.rename(columns={'Province ,Districts ,Jan ,Feb ,Mar ,Apr ,May ,Jun ,Jul ,Aug ,Sept ,Oct ,Nov ,Grand Total':'data'})

# %%
a.columns=['data']
a
# Out:
#                                                  data
# 0   3,306 KATHMANDU ,0,0,0,0,1,1,35,727,9891,2911,...
# 1   3,308 LALITPUR ,0,0,0,0,0,1,99,1558,6016,1809,...
# 2   3,307 BHAKTAPUR ,0,0,0,0,0,0,6,86,1151,4204,67...
# 3   3,312 MAKWANPUR ,0,0,0,0,0,0,221,337,2452,2220...
# 4   3,313 CHITAWAN ,0,0,0,0,0,3,4,24,995,1509,624,...
# ..                                                ...
# 73             3,303 RASUWA ,0,0,0,0,0,0,0,0,6,5,0,11
# 74             4,403 MUSTANG ,0,0,0,0,0,0,0,0,2,6,0,8
# 75               6,601 DOLPA ,0,0,0,0,0,0,0,1,1,2,1,5
# 76               6,603 HUMLA ,0,0,0,0,0,0,0,0,2,1,0,3
# 77  ,Grand Total ,11,3,15,18,25,93,720,3708,27529,...
#
# [78 rows x 1 columns]

# %%
a.head()
# Out:
#                                                 data
# 0  3,306 KATHMANDU ,0,0,0,0,1,1,35,727,9891,2911,...
# 1  3,308 LALITPUR ,0,0,0,0,0,1,99,1558,6016,1809,...
# 2  3,307 BHAKTAPUR ,0,0,0,0,0,0,6,86,1151,4204,67...
# 3  3,312 MAKWANPUR ,0,0,0,0,0,0,221,337,2452,2220...
# 4  3,313 CHITAWAN ,0,0,0,0,0,3,4,24,995,1509,624,...

# %%
a[['Province','Districts','Jan','Feb','Mar','Apr','May','Jun','Jul','Aug','Sept','Oct','Nov','Grand Total']]=a['data'].str.split(',',expand=True)

# %%
a
# Out:
#                                                  data Province  \
# 0   3,306 KATHMANDU ,0,0,0,0,1,1,35,727,9891,2911,...        3
# 1   3,308 LALITPUR ,0,0,0,0,0,1,99,1558,6016,1809,...        3
# 2   3,307 BHAKTAPUR ,0,0,0,0,0,0,6,86,1151,4204,67...        3
# 3   3,312 MAKWANPUR ,0,0,0,0,0,0,221,337,2452,2220...        3
# 4   3,313 CHITAWAN ,0,0,0,0,0,3,4,24,995,1509,624,...        3
# ..                                                ...      ...
# 73             3,303 RASUWA ,0,0,0,0,0,0,0,0,6,5,0,11        3
# 74             4,403 MUSTANG ,0,0,0,0,0,0,0,0,2,6,0,8        4
# 75               6,601 DOLPA ,0,0,0,0,0,0,0,1,1,2,1,5        6
# 76               6,603 HUMLA ,0,0,0,0,0,0,0,0,2,1,0,3        6
# 77  ,Grand Total ,11,3,15,18,25,93,720,3708,27529,...
#
#          Districts Jan Feb Mar Apr May Jun  Jul   Aug   Sept    Oct   Nov  \
# 0   306 KATHMANDU    0   0   0   0   1   1   35   727   9891   2911   561
# 1    308 LALITPUR    0   0   0   0   0   1   99  1558   6016   1809   120
# 2   307 BHAKTAPUR    0   0   0   0   0   0    6    86   1151   4204   677
# 3   312 MAKWANPUR    0   0   0   0   0   0  221   337   2452   2220   546
# 4    313 CHITAWAN    0   0   0   0   0   3    4    24    995   1509   624
# ..             ...  ..  ..  ..  ..  ..  ..  ...   ...    ...    ...   ...
# 73     303 RASUWA    0   0   0   0   0   0    0     0      6      5     0
# 74    403 MUSTANG    0   0   0   0   0   0    0     0      2      6     0
# 75      601 DOLPA    0   0   0   0   0   0    0     1      1      2     1
# 76      603 HUMLA    0   0   0   0   0   0    0     0      2      1     0
# 77    Grand Total   11   3  15  18  25  93  720  3708  27529  17889  3940
#
#    Grand Total
# 0        14127
# 1         9603
# 2         6124
# 3         5776
# 4         3159
# ..         ...
# 73          11
# 74           8
# 75           5
# 76           3
# 77       53951
#
# [78 rows x 15 columns]

# %%
a.drop('data',inplace=True,axis=1)

# %%
a.head()
# Out:
#   Province       Districts Jan Feb Mar Apr May Jun  Jul   Aug  Sept   Oct  \
# 0        3  306 KATHMANDU    0   0   0   0   1   1   35   727  9891  2911
# 1        3   308 LALITPUR    0   0   0   0   0   1   99  1558  6016  1809
# 2        3  307 BHAKTAPUR    0   0   0   0   0   0    6    86  1151  4204
# 3        3  312 MAKWANPUR    0   0   0   0   0   0  221   337  2452  2220
# 4        3   313 CHITAWAN    0   0   0   0   0   3    4    24   995  1509
#
#    Nov Grand Total
# 0  561       14127
# 1  120        9603
# 2  677        6124
# 3  546        5776
# 4  624        3159

# %%
a[['Code','District']]=a['Districts'].str.split(' ',1,expand=True)

# %%
a.head()
# Out:
#   Province       Districts Jan Feb Mar Apr May Jun  Jul   Aug  Sept   Oct  \
# 0        3  306 KATHMANDU    0   0   0   0   1   1   35   727  9891  2911
# 1        3   308 LALITPUR    0   0   0   0   0   1   99  1558  6016  1809
# 2        3  307 BHAKTAPUR    0   0   0   0   0   0    6    86  1151  4204
# 3        3  312 MAKWANPUR    0   0   0   0   0   0  221   337  2452  2220
# 4        3   313 CHITAWAN    0   0   0   0   0   3    4    24   995  1509
#
#    Nov Grand Total Code    District
# 0  561       14127  306  KATHMANDU
# 1  120        9603  308   LALITPUR
# 2  677        6124  307  BHAKTAPUR
# 3  546        5776  312  MAKWANPUR
# 4  624        3159  313   CHITAWAN

# %%
a.drop('Districts',inplace=True)
# Out:
#   Input In [20]
#     a.drop['Districts',inplace=True]
#                               ^
# SyntaxError: invalid syntax
